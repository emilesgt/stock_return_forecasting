# %% [markdown]
# # LIBRARIES, DATA, AND PREPROCESSING

# %% [markdown]
# ## Librairies

# %%
import sys
print(sys.executable)
# !{sys.executable} -m pip install yfinance
import yfinance as yf
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
# Out:
# c:\Users\Emile\AppData\Local\Programs\Python\Python312\python.exe
# Requirement already satisfied: yfinance in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.2.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (1.26.3)
# Requirement already satisfied: requests>=2.31 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\emile\appdata\roaming\python\python312\site-packages (from yfinance) (4.1.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2023.4)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (6.33.0)
# Requirement already satisfied: websockets>=13.0 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from curl_cffi>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\emile\appdata\roaming\python\python312\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\emile\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in c:\users\emile\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Import Data + CSV generation

# %%
tickers = {
    "DJ30": "^DJI",     # Dow Jones Industrial Average
    "SNP500": "^GSPC",  # S&P 500 Index
    "CAC40": "^FCHI"    # CAC 40 Index
}
start_date = "2018-01-01"
end_date = "2025-01-01"

for name, symbol in tickers.items():
    # Download data
    data = yf.download(symbol, start=start_date, end=end_date)[["Open", "High", "Low", "Close", "Volume"]]
    
    # Rename columns with prefix, e.g. "CAC40_Open", "CAC40_Close", etc.
    data = data.rename(columns={col: f"{name}__{col}" for col in data.columns})
    
    # Save to CSV
    filename = f"{name}_data.csv"
    data.to_csv(filename, index=True)
    print(data.head(), "\n")
# Out:
# C:\Users\Emile\AppData\Local\Temp\ipykernel_31348\4262377256.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, start=start_date, end=end_date)[["Open", "High", "Low", "Close", "Volume"]]
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Emile\AppData\Local\Temp\ipykernel_31348\4262377256.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, start=start_date, end=end_date)[["Open", "High", "Low", "Close", "Volume"]]
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Emile\AppData\Local\Temp\ipykernel_31348\4262377256.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, start=start_date, end=end_date)[["Open", "High", "Low", "Close", "Volume"]]
# [*********************100%***********************]  1 of 1 completed
# Price               Open          High           Low         Close     Volume
# Ticker              ^DJI          ^DJI          ^DJI          ^DJI       ^DJI
# Date
# 2018-01-02  24809.349609  24864.189453  24741.699219  24824.009766  341130000
# 2018-01-03  24850.449219  24941.919922  24825.550781  24922.679688  456790000
# 2018-01-04  24964.859375  25105.960938  24963.269531  25075.130859  403280000
# 2018-01-05  25114.919922  25299.789062  25112.009766  25295.869141  358020000
# 2018-01-08  25308.400391  25311.990234  25235.410156  25283.000000  341390000
#
# Price              Open         High          Low        Close      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2018-01-02  2683.729980  2695.889893  2682.360107  2695.810059  3397430000
# 2018-01-03  2697.850098  2714.370117  2697.770020  2713.060059  3544030000
# 2018-01-04  2719.310059  2729.290039  2719.070068  2723.989990  3697340000
# 2018-01-05  2731.330078  2743.449951  2727.919922  2743.149902  3239280000
# 2018-01-08  2742.669922  2748.510010  2737.600098  2747.709961  3246160000
#
# Price              Open         High          Low        Close    Volume
# Ticker            ^FCHI        ^FCHI        ^FCHI        ^FCHI     ^FCHI
# Date
# 2018-01-02  5318.740234  5318.740234  5258.660156  5288.600098  66802600
# 2018-01-03  5295.310059  5347.629883  5291.890137  5331.279785  75371700
# 2018-01-04  5360.009766  5430.720215  5360.009766  5413.689941  92583500
# 2018-01-05  5424.160156  5470.750000  5422.779785  5470.750000  76275800
# 2018-01-08  5483.470215  5499.149902  5478.919922  5487.419922  72318000

# %% [markdown]
# ## DATA PREPROCESSING

# %% [markdown]
# ## SPLITTING DATA

# %% [markdown]
# We will split  our data in the following way :
#
# 2015–2019 → Train
# 2020–2022 → Validation
# 2023–2024 → Test

# %% [markdown]
# # INDICATORS

# %% [markdown]
# - In this section, we will create the folloiwing indicators in order to apply them to the DJ30, SNP500 and CAC40 historical data :
#     - MACD
#     - RSI
#     - Moving Averages
#     - Volumes
#     - Momentum

# %% [markdown]
# ## MACD

# %% [markdown]
# What is the MACD?
#
# The Moving Average Convergence Divergence (MACD) is a **momentum indicator**
# used in technical analysis to reveal changes in the strength, direction,
# and duration of a trend in a stock’s price. It’s calculated as the difference
# between two Exponential Moving Averages (EMAs): a short-term one (usually 12 periods)
# and a long-term one (usually 26 periods).
#
#     The MACD line = EMA(12) – EMA(26)
#     The Signal line = EMA(9) of the MACD line
#     The Histogram = MACD – Signal
#
# When the MACD crosses above the Signal line, it may indicate **bullish momentum**;
# when it crosses below, it may suggest **bearish momentum**.

# %%
def compute_macd(df, close_col="Close", fast=12, slow=26, signal=9):

    if close_col not in df.columns:
        raise ValueError(f"Colonne '{close_col}' introuvable dans df.columns={list(df.columns)}")

    ema_fast = df[close_col].ewm(span=fast, adjust=False, min_periods=fast).mean()
    ema_slow = df[close_col].ewm(span=slow, adjust=False, min_periods=slow).mean()

    macd = ema_fast - ema_slow
    signal_line = macd.ewm(span=signal, adjust=False, min_periods=signal).mean()
    hist = macd - signal_line

    out = df.copy()
    out["MACD"] = macd
    out["MACD_signal"] = signal_line
    out["MACD_hist"] = hist
    return out


data_macd = compute_macd(data, close_col="Close")

# Aperçu
print(data_macd[["Close","MACD","MACD_signal","MACD_hist"]].tail())
# Out:
# Price             Close      MACD MACD_signal MACD_hist
# Ticker            ^FCHI
# Date
# 2024-12-23  7272.319824 -4.225831    1.695768 -5.921598
# 2024-12-24  7282.689941 -7.846351   -0.212656 -7.633695
# 2024-12-27  7355.370117 -4.795675   -1.129260 -3.666415
# 2024-12-30  7313.560059 -5.686168   -2.040641 -3.645526
# 2024-12-31  7380.740234 -0.959945   -1.824502  0.864557

# %%
import matplotlib.pyplot as plt

data_macd_filtered = data_macd.loc["2018-01-01":"2020-01-01"]

plt.figure(figsize=(12, 6))

plt.plot(data_macd_filtered.index, data_macd_filtered["MACD"], label="MACD", color="blue", linewidth=1.5)
plt.plot(data_macd_filtered.index, data_macd_filtered["MACD_signal"], label="Signal Line", color="orange", linewidth=1.5)

plt.bar(data_macd_filtered.index, data_macd_filtered["MACD_hist"], label="Histogram", color="gray", alpha=0.4)

plt.title("📊 MACD Indicator (2018–2021)", fontsize=14, fontweight='bold')
plt.xlabel("Date")
plt.ylabel("MACD Value")
plt.legend(loc="upper left")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Emile\AppData\Local\Temp\ipykernel_31348\975251957.py:17: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.tight_layout()
# C:\Users\Emile\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## RSI

# %% [markdown]
# The Relative Strength Index (RSI) is a momentum oscillator developed by J. Welles Wilder that measures the speed and magnitude of recent price movements to identify overbought or oversold market conditions. It oscillates between 0 and 100, typically using a 14-period window. When RSI rises above 70, it suggests that the asset may be overbought and could experience a pullback; when it falls below 30, it indicates that the asset may be oversold and due for a rebound. In trading and machine-learning contexts, RSI serves as a non-linear feature capturing momentum reversals and exhaustion in trends—helping models detect short-term shifts in market sentiment.

# %%
def compute_RSI(series, window=14):
    delta = series.diff()

    # Separate positive and negative changes
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)

    # Exponential moving averages (Wilder’s smoothing)
    avg_gain = gain.ewm(alpha=1/window, min_periods=window).mean()
    avg_loss = loss.ewm(alpha=1/window, min_periods=window).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# %%
data["RSI_14"] = compute_RSI(data["Close"], window=14)

# %%
data["RSI_14"] = data["RSI_14"].shift(1)
#to prevent look ahead bias

# %%
mask = (data.index >= "2018-01-01") & (data.index <= "2019-12-31")
subset = data.loc[mask]
plt.figure(figsize=(10, 4))
plt.plot(subset.index, subset["RSI_14"], label="RSI (14)", color="blue")
plt.axhline(70, color="red", linestyle="--", label="Overbought (70)")
plt.axhline(30, color="green", linestyle="--", label="Oversold (30)")
plt.title("RSI Indicator (AAPL) — 2018–2019")
plt.xlabel("Date")
plt.ylabel("RSI Value")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
